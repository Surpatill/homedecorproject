# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path=r'D:\homedecor\archive\Super_Store_data.csv'
data=pd.read_csv(data_path,encoding='utf=8',encoding_errors='ignore')

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 4      11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 2   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 3  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
# 4  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
# ...

# %%
data.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
category_sales=data.groupby('Category')['Sales'].sum().reset_index()
category_sales=category_sales.sort_values('Sales',ascending=False)
print(category_sales.head(5))
# Out:
#     Category        Sales
# 0  Furniture  741999.7953

# %%
print(data['Category'].nunique())
# Out:
# 1

# %%
Sub_Category_sales=data.groupby('Sub-Category')['Sales'].sum().reset_index()
Sub_Category_sales=Sub_Category_sales.sort_values('Sales',ascending=False)
print(Sub_Category_sales.head(5))
# Out:
#   Sub-Category        Sales
# 1       Chairs  328449.1030
# 3       Tables  206965.5320
# 0    Bookcases  114879.9963
# 2  Furnishings   91705.1640

# %% [markdown]
# 1. Chairs: The top-selling sub-category with sales of $328,449.10.
# 2. Tables: The second-best selling sub-category with sales of $206,965.53.
# 3. Bookcases: The third-best selling sub-category with sales of $114,879.99.
# 4. Furnishings: The fourth-best selling sub-category with sales of $91,705.16.

# %%
Chairs_data=data[data['Sub-Category']=='Chairs'].sort_values('Sales',ascending=False)
Tables_data=data[data['Sub-Category']=='Tables'].sort_values('Sales',ascending=False)
Bookcases_data=data[data['Sub-Category']=='Bookcases'].sort_values('Sales',ascending=False)
Furnishings_data=data[data['Sub-Category']=='Furnishings'].sort_values('Sales',ascending=False)

# %%
print("Top selling chairs:")
print(Chairs_data.head(5)[['Product Name','Sales']])
# Out:
# Top selling chairs:
#                                            Product Name     Sales
# 1517       HON 5400 Series Task Chairs for Big and Tall  4416.174
# 2001       HON 5400 Series Task Chairs for Big and Tall  3785.292
# 1070       HON 5400 Series Task Chairs for Big and Tall  3504.900
# 1276  Hon 4070 Series Pagoda Armless Upholstered Sta...  2888.127
# 366   Office Star - Professional Matrix Back Chair w...  2807.840

# %%
print("Top selling chairs:")
print(Tables_data.head(5)[['Product Name','Sales']])
# Out:
# Top selling chairs:
#                                            Product Name     Sales
# 2044  Chromcraft Bull-Nose Wood Oval Conference Tabl...  4297.644
# 259          Bretford Rectangular Conference Table Tops  3610.848
# 2092  Bush Advantage Collection Racetrack Conference...  3393.680
# 1447      Bretford CR8500 Series Meeting Room Furniture  2887.056
# 1802                       Balt Solid Wood Round Tables  2678.940

# %%
print("Top selling chairs:")
print(Bookcases_data.head(5)[['Product Name','Sales']])
# Out:
# Top selling chairs:
#                                            Product Name     Sales
# 2063  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.900
# 1232  Riverside Palais Royal Lawyers Bookcase, Royal...  4228.704
# 1365              DMI Eclipse Executive Suite Bookcases  4007.840
# 2047              DMI Eclipse Executive Suite Bookcases  3406.664
# 7     Riverside Palais Royal Lawyers Bookcase, Royal...  3083.430

# %%
print("Top selling chairs:")
print(Furnishings_data.head(5)[['Product Name','Sales']])
# Out:
# Top selling chairs:
#                                            Product Name     Sales
# 1551  Electrix Architect's Clamp-On Swing Arm Lamp, ...  1336.440
# 1573               Tenex Antistatic Computer Chair Mats  1196.860
# 135   Luxo Professional Fluorescent Magnifier Lamp w...  1049.200
# 882   Luxo Professional Fluorescent Magnifier Lamp w...  1049.200
# 194   Luxo Professional Fluorescent Magnifier Lamp w...  1007.232

# %% [markdown]
# Top-Selling Products by Sub-Category
#
# Chairs
#
# 1. HON 5400 Series Task Chairs for Big and Tall ($4416.17)
# 2. HON 5400 Series Task Chairs for Big and Tall ($3785.29)
# 3. HON 5400 Series Task Chairs for Big and Tall ($3504.90)
#
# Tables
#
# 1. Chromcraft Bull-Nose Wood Oval Conference Table ($4297.64)
# 2. Bretford Rectangular Conference Table Tops ($3610.85)
# 3. Bush Advantage Collection Racetrack Conference Table ($3393.68)
#
# Bookcases
#
# 1. Riverside Palais Royal Lawyers Bookcase, Royal Mahogany ($4404.90)
# 2. Riverside Palais Royal Lawyers Bookcase, Royal Mahogany ($4228.70)
# 3. DMI Eclipse Executive Suite Bookcases ($4007.84)
#
# Furnishings
#
# 1. Electrix Architect's Clamp-On Swing Arm Lamp, Black ($1336.44)
# 2. Tenex Antistatic Computer Chair Mats ($1196.86)
# 3. Luxo Professional Fluorescent Magnifier Lamp with Clamp ($1049.20)

# %%
product_sales = data.groupby('Product Name')['Sales'].sum().reset_index()
product_sales = product_sales.sort_values('Sales', ascending=False)
print(product_sales)
# Out:
#                                           Product Name       Sales
# 206       HON 5400 Series Task Chairs for Big and Tall  21870.5760
# 321  Riverside Palais Royal Lawyers Bookcase, Royal...  15610.9656
# 41          Bretford Rectangular Conference Table Tops  12995.2915
# 201      Global Troy Executive Leather Low-Back Tilter  12975.3820
# 325                           SAFCO Arco Folding Chair  11572.7800
# ..                                                 ...         ...
# 69                       Contemporary Borderless Frame     36.1620
# 318                       Regeneration Desk Collection     35.9040
# 138  Eldon Regeneration Recycled Desk Accessories, ...     33.7560
# 110            Eldon 300 Class Desk Accessories, Black     29.7000
# 285               Nu-Dell EZ-Mount Plastic Wall Frames     19.7000
#
# [380 rows x 2 columns]

# %%
plt.bar(category_sales['Category'], category_sales['Sales'])
plt.xlabel('Category')
plt.ylabel('Sales')
plt.title('Top-Selling Categories')
plt.show()

# %%
plt.bar(Sub_Category_sales['Sub-Category'], Sub_Category_sales['Sales'])
plt.xlabel('Sub-Category')
plt.ylabel('Sales')
plt.title('Top-Selling Sub-Categories')
plt.show()

# %%
top_products = product_sales.nlargest(30, 'Sales') 
plt.figure(figsize=(15,8))  
plt.bar(top_products['Product Name'], top_products['Sales'])
plt.xlabel('Product Name')
plt.ylabel('Sales')
plt.title('Top-Selling Products')
plt.xticks(rotation=90, fontsize=8) 
plt.gca().tick_params(axis='x', labelsize=8)  
plt.tight_layout()  
plt.show()

# %%
customer_segments = data['Segment'].value_counts()
print(customer_segments)
plt.bar(customer_segments.index, customer_segments.values)
plt.xlabel('Segment')
plt.ylabel('Count')
plt.title('Customer Segmentation')
plt.show()
# Out:
# Segment
# Consumer       1113
# Corporate       646
# Home Office     362
# Name: count, dtype: int64

# %%
top_30_sales_trends = data.nlargest(30, 'Sales')
plt.figure(figsize=(12,6))
plt.plot(top_30_sales_trends['Order Date'], top_30_sales_trends['Sales'], marker='o')
plt.xlabel('Order Date')
plt.ylabel('Sales')
plt.title('Top 30 Sales Trends by Order Date')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
